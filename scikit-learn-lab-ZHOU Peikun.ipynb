# %%
    # Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
# Out:
# 1
# 0.90000000000000002220
# 2
# 0.90000000000000002220
# 3
# 0.90000000000000002220
# 4
# 0.90000000000000002220
# 5
# 0.90000000000000002220
# 6
# 0.90000000000000002220
# 7
# 0.90000000000000002220
# 8
# 1.00000000000000000000
# 9
# 1.00000000000000000000
# 10
# 1.00000000000000000000
# 11
# 1.00000000000000000000
# 12
# 1.00000000000000000000
# 13
# 0.90000000000000002220
# 14
# 1.00000000000000000000
# 15
# 0.90000000000000002220
# 16
# 1.00000000000000000000
# 17
# 1.00000000000000000000
# 18
# 1.00000000000000000000
# 19
# 1.00000000000000000000
# 20
# 1.00000000000000000000
# 21
# 1.00000000000000000000
# 22
# 1.00000000000000000000
# 23
# 1.00000000000000000000
# 24
# 1.00000000000000000000
# 25
# 0.90000000000000002220
# 26
# 1.00000000000000000000
# 27
# 1.00000000000000000000
# 28
# 1.00000000000000000000
# 29
# 1.00000000000000000000
# 30
# 1.00000000000000000000
# 31
# 1.00000000000000000000
# 32
# 1.00000000000000000000
# 33
# 1.00000000000000000000
# 34
# ...

# %%
# To test different parameter k's result, I added a simple loop. At the very beginning, I only test k from 1 to 15, once I found that results are not 
# clair enough, I increaed k's range to (0, 150), then I got these results.

# With the help of matplotlib, we can easily get the result graph

# %%
# Code added with pyplot grap
# Import classes
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Create figure
plt.figure(1)

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
	plt.figure(1)
	plt.plot(i, accuracy_score(iris_y_test, knn.predict(iris_X_test)))

plt.show()
# Out:
# 1
# 0.90000000000000002220
# 2
# 0.90000000000000002220
# 3
# 0.90000000000000002220
# 4
# 0.90000000000000002220
# 5
# 0.90000000000000002220
# 6
# 0.90000000000000002220
# 7
# 0.90000000000000002220
# 8
# 1.00000000000000000000
# 9
# 1.00000000000000000000
# 10
# 1.00000000000000000000
# 11
# 1.00000000000000000000
# 12
# 1.00000000000000000000
# 13
# 0.90000000000000002220
# 14
# 1.00000000000000000000
# 15
# 0.90000000000000002220
# 16
# 1.00000000000000000000
# 17
# 1.00000000000000000000
# 18
# 1.00000000000000000000
# 19
# 1.00000000000000000000
# 20
# 1.00000000000000000000
# 21
# 1.00000000000000000000
# 22
# 1.00000000000000000000
# 23
# 1.00000000000000000000
# 24
# 1.00000000000000000000
# 25
# 0.90000000000000002220
# 26
# 1.00000000000000000000
# 27
# 1.00000000000000000000
# 28
# 1.00000000000000000000
# 29
# 1.00000000000000000000
# 30
# 1.00000000000000000000
# 31
# 1.00000000000000000000
# 32
# 1.00000000000000000000
# 33
# 1.00000000000000000000
# 34
# ...

# %%
# According to the graph, the result is not stable. When k is 8, 9, 10, 11, 12, results are 1; when k increasing to 16 or more, result is keep at 1; however, once
# k is equal to 93, the result is decreased to 0.8. 

# In my opinion, I thought we could get the most optimal k and the others are not good enough, but I got more than one. I tried searching it but 
# I am not sure about it.  

# Thanks

# ZHOU Peikun
