# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,15):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
	print knn.predict(iris_X_test)
	print iris_y_test
	print accuracy_score(iris_y_test, knn.predict(iris_X_test))
# Out:
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0

# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,15):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
	print knn.predict(iris_X_test)
	print iris_y_test
    accuracy_score(iris_y_test, knn.predict(iris_X_test))
# Out:
#   File "<ipython-input-2-12cd2839a791>", line 31
#     accuracy_score(iris_y_test, knn.predict(iris_X_test))
#                                                          ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,15):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
	print knn.predict(iris_X_test)
	print iris_y_test
	print accuracy_score(iris_y_test, knn.predict(iris_X_test))
# Out:
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0

# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
	print knn.predict(iris_X_test)
	print iris_y_test
	print accuracy_score(iris_y_test, knn.predict(iris_X_test))
# Out:
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.9
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 1 1 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 1.0
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8
# [1 2 2 0 0 0 2 1 2 0]
# [1 1 1 0 0 0 2 1 2 0]
# 0.8

# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,15):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#print knn.predict(iris_X_test)
#print iris_y_test
    print i
	print accuracy_score(iris_y_test, knn.predict(iris_X_test))
# Out:
#   File "<ipython-input-5-14e01aef55f5>", line 31
#     print i
#            ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
# Out:
# 1
# 0.90000000000000002220
# 2
# 0.90000000000000002220
# 3
# 0.90000000000000002220
# 4
# 0.90000000000000002220
# 5
# 0.90000000000000002220
# 6
# 0.90000000000000002220
# 7
# 0.90000000000000002220
# 8
# 1.00000000000000000000
# 9
# 1.00000000000000000000
# 10
# 1.00000000000000000000
# 11
# 1.00000000000000000000
# 12
# 1.00000000000000000000
# 13
# 0.90000000000000002220
# 14
# 1.00000000000000000000
# 15
# 0.90000000000000002220
# 16
# 1.00000000000000000000
# 17
# 1.00000000000000000000
# 18
# 1.00000000000000000000
# 19
# 1.00000000000000000000
# 20
# 1.00000000000000000000
# 21
# 1.00000000000000000000
# 22
# 1.00000000000000000000
# 23
# 1.00000000000000000000
# 24
# 1.00000000000000000000
# 25
# 0.90000000000000002220
# 26
# 1.00000000000000000000
# 27
# 1.00000000000000000000
# 28
# 1.00000000000000000000
# 29
# 1.00000000000000000000
# 30
# 1.00000000000000000000
# 31
# 1.00000000000000000000
# 32
# 1.00000000000000000000
# 33
# 1.00000000000000000000
# 34
# 1.00000000000000000000
# 35
# 1.00000000000000000000
# 36
# 1.00000000000000000000
# 37
# 1.00000000000000000000
# 38
# 1.00000000000000000000
# 39
# 1.00000000000000000000
# 40
# 1.00000000000000000000
# 41
# 1.00000000000000000000
# 42
# 1.00000000000000000000
# 43
# 1.00000000000000000000
# 44
# 1.00000000000000000000
# 45
# 1.00000000000000000000
# 46
# 1.00000000000000000000
# 47
# 1.00000000000000000000
# 48
# 1.00000000000000000000
# 49
# 1.00000000000000000000
# 50
# 1.00000000000000000000
# 51
# 1.00000000000000000000
# 52
# 1.00000000000000000000
# 53
# 1.00000000000000000000
# 54
# 1.00000000000000000000
# 55
# 1.00000000000000000000
# 56
# 1.00000000000000000000
# 57
# 1.00000000000000000000
# 58
# 1.00000000000000000000
# 59
# 1.00000000000000000000
# 60
# 1.00000000000000000000
# 61
# 1.00000000000000000000
# 62
# 1.00000000000000000000
# 63
# 1.00000000000000000000
# 64
# 1.00000000000000000000
# 65
# 1.00000000000000000000
# 66
# 1.00000000000000000000
# 67
# 1.00000000000000000000
# 68
# 1.00000000000000000000
# 69
# 1.00000000000000000000
# 70
# 1.00000000000000000000
# 71
# 1.00000000000000000000
# 72
# 1.00000000000000000000
# 73
# 1.00000000000000000000
# 74
# 1.00000000000000000000
# 75
# 1.00000000000000000000
# 76
# 1.00000000000000000000
# 77
# 1.00000000000000000000
# 78
# 1.00000000000000000000
# 79
# 1.00000000000000000000
# 80
# 1.00000000000000000000
# 81
# 1.00000000000000000000
# 82
# 1.00000000000000000000
# 83
# 1.00000000000000000000
# 84
# 1.00000000000000000000
# 85
# 0.90000000000000002220
# 86
# 1.00000000000000000000
# 87
# 1.00000000000000000000
# 88
# 1.00000000000000000000
# 89
# 1.00000000000000000000
# 90
# 1.00000000000000000000
# 91
# 1.00000000000000000000
# 92
# 1.00000000000000000000
# 93
# 0.80000000000000004441
# 94
# 0.80000000000000004441
# 95
# 0.80000000000000004441
# 96
# 0.80000000000000004441
# 97
# 0.80000000000000004441
# 98
# 0.80000000000000004441
# 99
# 0.80000000000000004441

# %%
import matplotlib.pyplot as plt
# Out:
# /home/peikun/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.figure(1)

# %%
plt.plot(i, accuracy_score(iris_y_test, knn.predict(iris_X_test)))

# %%
plt.show()

# %%
# Import classes
import numpy as np
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
    import matplotlib.pyplot as plt
    plt.figure(1) 
    plt.plot(i, accuracy_score(iris_y_test, knn.predict(iris_X_test)))
    plt.show()
# Out:
#   File "<ipython-input-11-daad03babc2b>", line 33
#     import matplotlib.pyplot as plt
#                                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Import classes
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
    plt.figure(1) 
    plt.plot(i, accuracy_score(iris_y_test, knn.predict(iris_X_test)))
    plt.show()
# Out:
#   File "<ipython-input-12-bf2e0418a91b>", line 34
#     plt.figure(1)
#                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Import classes
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
    plt.figure(2) 
    plt.plot(i, accuracy_score(iris_y_test, knn.predict(iris_X_test)))
    plt.show()
# Out:
#   File "<ipython-input-13-6148d4232510>", line 34
#     plt.figure(2)
#                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
plt.figure(1) # 创建图表1
plt.figure(2) # 创建图表2
ax1 = plt.subplot(211) # 在图表2中创建子图1
ax2 = plt.subplot(212) # 在图表2中创建子图2
 
x = np.linspace(0, 3, 100)
for i in xrange(5):
    plt.figure(1)  #❶ # 选择图表1
    plt.plot(x, np.exp(i*x/3))
    plt.sca(ax1)   #❷ # 选择图表2的子图1
    plt.plot(x, np.sin(i*x))
    plt.sca(ax2)  # 选择图表2的子图2
    plt.plot(x, np.cos(i*x))
 
plt.show()

# %%
  # Import classes
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# Load and parse the data file
iris = datasets.load_iris()
iris_X = iris.data
iris_y = iris.target
np.unique(iris_y)

# Split iris data in train and test data
# A random permutation, to split the data randomly 
np.random.seed(0)
indices = np.random.permutation(len(iris_X))
iris_X_train = iris_X[indices[:-10]]
iris_y_train = iris_y[indices[:-10]]
iris_X_test  = iris_X[indices[-10:]]
iris_y_test  = iris_y[indices[-10:]]

# Train a k-nearest-neighbor model
# Create and fit a k-nearest-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
for i in range(1,100):
	knn = KNeighborsClassifier(i)
	knn.fit(iris_X_train, iris_y_train)

# Evaluate model on test instances and comput test error
	from sklearn.metrics import accuracy_score
#	print knn.predict(iris_X_test)
#	print iris_y_test
	print i
	print "{:10.20f}".format(accuracy_score(iris_y_test, knn.predict(iris_X_test)))
